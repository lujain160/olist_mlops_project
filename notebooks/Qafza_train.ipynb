# %% [markdown]
# # By Lujain Abdullah
# ------------------------------------
# ### Classification

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine , text
import os
from dotenv import load_dotenv

# %%
# create the engine
load_dotenv()
password=os.getenv("DB_PASSWORD")
user=os.getenv("DB_USER")
host=os.getenv("DB_HOST")
port=os.getenv("DB_PORT")
db_name=os.getenv("DB_NAME")

# %%
server_engine=create_engine(f"mysql+pymysql://{user}:{password}@{host}:{port}")

# %%
# write all the datasets in the tables
tables={
    "customers":"olist_customers_dataset.csv",
    "orders":"olist_orders_dataset.csv",
    "items":"olist_order_items_dataset.csv",
    "products":"olist_products_dataset.csv",
    "payments":"olist_order_payments_dataset.csv",
    "reviews":"olist_order_reviews_dataset.csv",
    "sellers":"olist_sellers_dataset.csv",
    "geolocation":"olist_geolocation_dataset.csv"
}

# %%
with server_engine.connect() as conn:
    conn.execute(text("CREATE DATABASE IF NOT EXISTS olist_db;"))
    conn.commit()
   
# create engine with the specific database name 
engine=create_engine(f"mysql+pymysql://{user}:{password}@{host}:{port}/{db_name}")

# Using loop for all the datasets to write each CSV file as a table into MySQL
for table_name, file_path in tables.items():
    df=pd.read_csv(file_path)
    df.to_sql(table_name, con=engine, if_exists='replace', index=False)
    print(f"Table '{table_name}' loaded successfully.")
# Out:
# Table 'customers' loaded successfully.
# Table 'orders' loaded successfully.
# Table 'items' loaded successfully.
# Table 'products' loaded successfully.
# Table 'payments' loaded successfully.
# Table 'reviews' loaded successfully.
# Table 'sellers' loaded successfully.
# Table 'geolocation' loaded successfully.
